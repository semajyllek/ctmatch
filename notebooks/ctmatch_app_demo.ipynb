# %%
# !git clone https://github.com/semajyllek/ctmatch.git
# Out:
# Cloning into 'ctmatch'...
# remote: Enumerating objects: 1694, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 1694 (delta 107), reused 100 (delta 55), pack-reused 1540
# Receiving objects: 100% (1694/1694), 473.97 KiB | 16.34 MiB/s, done.
# Resolving deltas: 100% (1144/1144), done.

# %%
# !pip install -r /content/ctmatch/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers (from -r /content/ctmatch/requirements.txt (line 6))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface_hub (from -r /content/ctmatch/requirements.txt (line 7))
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r /content/ctmatch/requirements.txt (line 8)) (1.2.2)
# Collecting transformers (from -r /content/ctmatch/requirements.txt (line 9))
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 98.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from -r /content/ctmatch/requirements.txt (line 11)) (3.7.1)
# Collecting accelerate (from -r /content/ctmatch/requirements.txt (line 12))
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 14.2 MB/s eta 0:00:00
# Collecting datasets (from -r /content/ctmatch/requirements.txt (line 13))
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 28.3 MB/s eta 0:00:00
# Collecting evaluate (from -r /content/ctmatch/requirements.txt (line 14))
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r /content/ctmatch/requirements.txt (line 15)) (1.5.3)
# Collecting openai (from -r /content/ctmatch/requirements.txt (line 16))
#   Downloading openai-0.27.6-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from -r /content/ctmatch/requirements.txt (line 17)) (4.9.2)
# Collecting gradio (from -r /content/ctmatch/requirements.txt (line 19))
#   Downloading gradio-3.30.0-py3-none-any.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (3.8.1)
# Collecting sentencepiece (from sentence-transformers->-r /content/ctmatch/requirements.txt (line 6))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (23.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/ctmatch/requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r /content/ctmatch/requirements.txt (line 8)) (3.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/ctmatch/requirements.txt (line 9)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r /content/ctmatch/requirements.txt (line 9))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.7 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (2.8.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r /content/ctmatch/requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->-r /content/ctmatch/requirements.txt (line 13)) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.2 MB/s eta 0:00:00
# Collecting xxhash (from datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 27.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 19.3 MB/s eta 0:00:00
# Collecting aiohttp (from datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.0 MB/s eta 0:00:00
# Collecting responses<0.19 (from datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r /content/ctmatch/requirements.txt (line 15)) (2022.7.1)
# Collecting aiofiles (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/ctmatch/requirements.txt (line 19)) (4.2.2)
# Collecting fastapi (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading fastapi-0.95.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 8.9 MB/s eta 0:00:00
# Collecting ffmpy (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client>=0.2.4 (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading gradio_client-0.2.4-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.9/287.9 kB 35.8 MB/s eta 0:00:00
# Collecting httpx (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/ctmatch/requirements.txt (line 19)) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/ctmatch/requirements.txt (line 19)) (2.2.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/ctmatch/requirements.txt (line 19)) (2.1.2)
# Collecting mdit-py-plugins<=0.3.3 (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 7.7 MB/s eta 0:00:00
# Collecting orjson (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading orjson-3.8.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/ctmatch/requirements.txt (line 19)) (1.10.7)
# Collecting pydub (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: pygments>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r /content/ctmatch/requirements.txt (line 19)) (2.14.0)
# Collecting python-multipart (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.8 MB/s eta 0:00:00
# Collecting semantic-version (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.3 MB/s eta 0:00:00
# Collecting websockets>=10.0 (from gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio->-r /content/ctmatch/requirements.txt (line 19)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio->-r /content/ctmatch/requirements.txt (line 19)) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio->-r /content/ctmatch/requirements.txt (line 19)) (0.12.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13)) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 17.3 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.8 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->-r /content/ctmatch/requirements.txt (line 13))
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio->-r /content/ctmatch/requirements.txt (line 19)) (0.1.2)
# Collecting linkify-it-py<3,>=1 (from markdown-it-py[linkify]>=2.0.0->gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->-r /content/ctmatch/requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->-r /content/ctmatch/requirements.txt (line 7)) (3.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (16.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio->-r /content/ctmatch/requirements.txt (line 19)) (8.1.3)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.0 MB/s eta 0:00:00
# Collecting starlette<0.27.0,>=0.26.1 (from fastapi->gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 10.1 MB/s eta 0:00:00
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx->gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading httpcore-0.17.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->-r /content/ctmatch/requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio->-r /content/ctmatch/requirements.txt (line 19)) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->-r /content/ctmatch/requirements.txt (line 19)) (0.19.3)
# Collecting uc-micro-py (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio->-r /content/ctmatch/requirements.txt (line 19))
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers->-r /content/ctmatch/requirements.txt (line 6)) (1.3.0)
# Building wheels for collected packages: sentence-transformers, ffmpy
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=c1acdc1c391488a6b52c319439b9d5f1daa11aa2498baeada0c2e1bcead66937
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4694 sha256=e3e286fdc22607fcf4f03af70df5d44be57e3bff9a488a5f92227803d98578c4
#   Stored in directory: /root/.cache/pip/wheels/0c/c2/0e/3b9c6845c6a4e35beb90910cc70d9ac9ab5d47402bd62af0df
# Successfully built sentence-transformers ffmpy
# Installing collected packages: tokenizers, sentencepiece, pydub, ffmpy, xxhash, websockets, uc-micro-py, semantic-version, python-multipart, orjson, multidict, h11, frozenlist, dill, async-timeout, aiofiles, yarl, uvicorn, starlette, responses, multiprocess, mdit-py-plugins, linkify-it-py, huggingface_hub, httpcore, aiosignal, transformers, httpx, fastapi, aiohttp, openai, gradio-client, gradio, datasets, evaluate, sentence-transformers, accelerate
# Successfully installed accelerate-0.19.0 aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 evaluate-0.4.0 fastapi-0.95.1 ffmpy-0.3.0 frozenlist-1.3.3 gradio-3.30.0 gradio-client-0.2.4 h11-0.14.0 httpcore-0.17.0 httpx-0.24.0 huggingface_hub-0.14.1 linkify-it-py-2.0.2 mdit-py-plugins-0.3.3 multidict-6.0.4 multiprocess-0.70.14 openai-0.27.6 orjson-3.8.12 pydub-0.25.1 python-multipart-0.0.6 responses-0.18.0 semantic-version-2.10.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 starlette-0.26.1 tokenizers-0.13.3 transformers-4.29.1 uc-micro-py-1.0.2 uvicorn-0.22.0 websockets-11.0.3 xxhash-3.2.0 yarl-1.9.2

# %%
import sys
sys.path.insert(1, '/content/ctmatch')

# %%
import gradio as gr
from ctmatch.match import CTMatch, PipeConfig

# %%
def ctmatch_web_api(topic_query: str) -> str:
   
    pipe_config = PipeConfig(
        ir_setup=True,
        filters=['svm', "classifier"],
    )
    
    ctm = CTMatch(pipe_config)
    return '\n'.join([f"{nid}: {txt}" for nid, txt in ctm.match_pipeline(topic_query, top_k=5)])


with gr.Blocks(css=".gradio-container {background-color: #00CED1}") as demo:
    name = gr.Textbox(lines=5, label="patient description", placeholder="Patient is a 45-year-old man with a history of anaplastic astrocytoma...")
    output = gr.Textbox(lines=10, label="matching trials")
    greet_btn = gr.Button("match")
    greet_btn.click(fn=ctmatch_web_api, inputs=name, outputs=output, api_name="match")

demo.queue().launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://bb570931d616537037.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://bb570931d616537037.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Downloading (…)okenizer_config.json:   0%|          | 0.00/394 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/228k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/1.85k [00:00<?, ?B/s]
# Downloading and preparing dataset text/semaj83--ctmatch_ir to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-208bbee6f8b55a7a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/4.50M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-208bbee6f8b55a7a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading and preparing dataset text/semaj83--ctmatch_ir to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-579c003586d3eeee/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.76G [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-579c003586d3eeee/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading and preparing dataset text/semaj83--ctmatch_ir to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-15a360be6a691604/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-15a360be6a691604/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading and preparing dataset text/semaj83--ctmatch_ir to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-6e778ee9831b44dc/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/437M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-6e778ee9831b44dc/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/900 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# INFO:ctmatch.match:running svm filter on 374648 documents
# INFO:ctmatch.match:running classifier filter on 1000 documents
# WARNING:datasets.builder:Found cached dataset text (/root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-208bbee6f8b55a7a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
#   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset text (/root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-579c003586d3eeee/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
#   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset text (/root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-15a360be6a691604/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
#   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:datasets.builder:Found cached dataset text (/root/.cache/huggingface/datasets/semaj83___text/semaj83--ctmatch_ir-6e778ee9831b44dc/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
#   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:ctmatch.match:running svm filter on 374648 documents
# INFO:ctmatch.match:running classifier filter on 1000 documents
